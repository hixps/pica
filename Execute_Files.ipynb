# %%
import os
import tqdm

import luxeics

import yaml
input_filename = f"{os.getcwd()}{os.sep}YML_Files{os.sep}L_Para_Run"


with open( input_filename + '.yml', 'r' ) as stream:
               
            
            
            input_dict = yaml.load(stream, Loader=yaml.SafeLoader)
            

            directory	=input_dict['control']['folder']


path = f"{os.getcwd()}{os.sep}Photon_Density{os.sep}{directory}{os.sep}Yml_Files"



os.mkdir(f'{os.getcwd()}{os.sep}Photon_Density{os.sep}{directory}{os.sep}H_Five')




object = os.scandir(path)
print("Files and Directories in '% s':" % path)
for n in object :
    





        luxeics.main_program(  f'{path}{os.sep}{n.name}' )
        print(n.name)
object.close()
# Out:
# Files and Directories in 'C:\Users\Dupish\Documents\GitHub\luxeics\Photon_Density\L_Para_Run\Yml_Files':
# >>> mode == full
# [10000000, 10000000, 10000000, 10000000, 10000000, 10000000, 10000000, 10000000, 10000000, 10000000] 100000000 100000000
#  >> rescale pulse duration: 8549.40 -> 800.00: sigma_rescalefactor = 10.69
#  >> number_electrons   = 624150947
#  >> sample_electrons   = 100000000
#  >> electron weight    = 6.242
#  >> MC sampling
#   > batch 0 : 10000000 macroelectrons
#    base photon weight : 37.055180100863694
#    number photons     : 858
#    total photon number: 858
#   > batch 1 : 10000000 macroelectrons
#    base photon weight : 42.70011919885137
#    number photons     : 759
#    total photon number: 1617
#   > batch 2 : 10000000 macroelectrons
#    base photon weight : 41.66462653785632
#    number photons     : 799
#    total photon number: 2416
#   > batch 3 : 10000000 macroelectrons
#    base photon weight : 40.939414417081124
# ...

# %%
import os
import tqdm

import luxeics

import yaml
input_filename = f"{os.getcwd()}{os.sep}YML_Files{os.sep}Sigmax_Sigmay10"


with open( input_filename + '.yml', 'r' ) as stream:
               
            
            
            input_dict = yaml.load(stream, Loader=yaml.SafeLoader)
            

            directory	=input_dict['control']['folder']


path = f"{os.getcwd()}{os.sep}Photon_Density{os.sep}{directory}{os.sep}Yml_Files"



os.mkdir(f'{os.getcwd()}{os.sep}Photon_Density{os.sep}{directory}{os.sep}H_Five')




object = os.scandir(path)
print("Files and Directories in '% s':" % path)
for n in object :
    





        luxeics.main_program(  f'{path}{os.sep}{n.name}' )
        print(n.name)
object.close()
# Out:
# Files and Directories in 'C:\Users\Dupish\Documents\GitHub\luxeics\Photon_Density\Sigmax_Sigmay10\Yml_Files':
# >>> mode == full
# [10000000, 10000000, 10000000, 10000000, 10000000, 10000000, 10000000, 10000000, 10000000, 10000000] 100000000 100000000
#  >> rescale pulse duration: 8549.40 -> 800.00: sigma_rescalefactor = 10.69
#  >> number_electrons   = 624150947
#  >> sample_electrons   = 100000000
#  >> electron weight    = 6.242
#  >> MC sampling
#   > batch 0 : 10000000 macroelectrons
#    base photon weight : 48.106221845300624
#    number photons     : 1549
#    total photon number: 1549
#   > batch 1 : 10000000 macroelectrons
#    base photon weight : 49.80207800133977
#    number photons     : 1495
#    total photon number: 3044
#   > batch 2 : 10000000 macroelectrons
#    base photon weight : 51.06449168925865
#    number photons     : 1407
#    total photon number: 4451
#   > batch 3 : 10000000 macroelectrons
#    base photon weight : 53.4672129444978
# ...

# %%
import os
import tqdm

import luxeics

import yaml
input_filename = f"{os.getcwd()}{os.sep}YML_Files{os.sep}Sigmax_Sigmay15"


with open( input_filename + '.yml', 'r' ) as stream:
               
            
            
            input_dict = yaml.load(stream, Loader=yaml.SafeLoader)
            

            directory	=input_dict['control']['folder']


path = f"{os.getcwd()}{os.sep}Photon_Density{os.sep}{directory}{os.sep}Yml_Files"



os.mkdir(f'{os.getcwd()}{os.sep}Photon_Density{os.sep}{directory}{os.sep}H_Five')




object = os.scandir(path)
print("Files and Directories in '% s':" % path)
for n in object :
    





        luxeics.main_program(  f'{path}{os.sep}{n.name}' )
        print(n.name)
object.close()
# Out:
# Files and Directories in 'C:\Users\Dupish\Documents\GitHub\luxeics\Photon_Density\Sigmax_Sigmay15\Yml_Files':
# >>> mode == full
# [10000000, 10000000, 10000000, 10000000, 10000000, 10000000, 10000000, 10000000, 10000000, 10000000] 100000000 100000000
#  >> rescale pulse duration: 8549.40 -> 800.00: sigma_rescalefactor = 10.69
#  >> number_electrons   = 624150947
#  >> sample_electrons   = 100000000
#  >> electron weight    = 6.242
#  >> MC sampling
#   > batch 0 : 10000000 macroelectrons
#    base photon weight : 39.27412296556441
#    number photons     : 899
#    total photon number: 899
#   > batch 1 : 10000000 macroelectrons
#    base photon weight : 39.79072657954818
#    number photons     : 870
#    total photon number: 1769
#   > batch 2 : 10000000 macroelectrons
#    base photon weight : 40.13387179089464
#    number photons     : 852
#    total photon number: 2621
#   > batch 3 : 10000000 macroelectrons
#    base photon weight : 36.282846754267375
# ...

# %%
import os
import tqdm

import luxeics

import yaml
input_filename = f"{os.getcwd()}{os.sep}YML_Files{os.sep}Sigmax_Sigmay20"


with open( input_filename + '.yml', 'r' ) as stream:
               
            
            
            input_dict = yaml.load(stream, Loader=yaml.SafeLoader)
            

            directory	=input_dict['control']['folder']


path = f"{os.getcwd()}{os.sep}Photon_Density{os.sep}{directory}{os.sep}Yml_Files"



os.mkdir(f'{os.getcwd()}{os.sep}Photon_Density{os.sep}{directory}{os.sep}H_Five')




object = os.scandir(path)
print("Files and Directories in '% s':" % path)
for n in object :
    





        luxeics.main_program(  f'{path}{os.sep}{n.name}' )
        print(n.name)
object.close()
# Out:
# Files and Directories in 'C:\Users\Dupish\Documents\GitHub\luxeics\Photon_Density\Sigmax_Sigmay20\Yml_Files':
# >>> mode == full
# [10000000, 10000000, 10000000, 10000000, 10000000, 10000000, 10000000, 10000000, 10000000, 10000000] 100000000 100000000
#  >> rescale pulse duration: 8549.40 -> 800.00: sigma_rescalefactor = 10.69
#  >> number_electrons   = 624150947
#  >> sample_electrons   = 100000000
#  >> electron weight    = 6.242
#  >> MC sampling
#   > batch 0 : 10000000 macroelectrons
#    base photon weight : 40.74882267585769
#    number photons     : 483
#    total photon number: 483
#   > batch 1 : 10000000 macroelectrons
#    base photon weight : 34.340884898278574
#    number photons     : 583
#    total photon number: 1066
#   > batch 2 : 10000000 macroelectrons
#    base photon weight : 37.871165440034105
#    number photons     : 528
#    total photon number: 1594
#   > batch 3 : 10000000 macroelectrons
#    base photon weight : 35.102148628806155
# ...

# %%
import os
import tqdm

import luxeics

import yaml
input_filename = f"{os.getcwd()}{os.sep}YML_Files{os.sep}Sigmax_Sigmay25"


with open( input_filename + '.yml', 'r' ) as stream:
               
            
            
            input_dict = yaml.load(stream, Loader=yaml.SafeLoader)
            

            directory	=input_dict['control']['folder']
 

path = f"{os.getcwd()}{os.sep}Photon_Density{os.sep}{directory}{os.sep}Yml_Files"



os.mkdir(f'{os.getcwd()}{os.sep}Photon_Density{os.sep}{directory}{os.sep}H_Five')




object = os.scandir(path)
print("Files and Directories in '% s':" % path)
for n in object :
    





        luxeics.main_program(  f'{path}{os.sep}{n.name}' )
        print(n.name)
object.close()
# Out:
# Files and Directories in 'C:\Users\Dupish\Documents\GitHub\luxeics\Photon_Density\Sigmax_Sigmay25\Yml_Files':
# >>> mode == full
# [10000000, 10000000, 10000000, 10000000, 10000000, 10000000, 10000000, 10000000, 10000000, 10000000] 100000000 100000000
#  >> rescale pulse duration: 8549.40 -> 800.00: sigma_rescalefactor = 10.69
#  >> number_electrons   = 624150947
#  >> sample_electrons   = 100000000
#  >> electron weight    = 6.242
#  >> MC sampling
#   > batch 0 : 10000000 macroelectrons
#    base photon weight : 37.88304486318248
#    number photons     : 332
#    total photon number: 332
#   > batch 1 : 10000000 macroelectrons
#    base photon weight : 39.926852224740536
#    number photons     : 379
#    total photon number: 711
#   > batch 2 : 10000000 macroelectrons
#    base photon weight : 34.55901375328613
#    number photons     : 365
#    total photon number: 1076
#   > batch 3 : 10000000 macroelectrons
#    base photon weight : 36.94113851090754
# ...

# %%
import os
import tqdm

import luxeics

import yaml
input_filename = f"{os.getcwd()}{os.sep}YML_Files{os.sep}L_3_8{os.sep}Sigmax_Sigmay5"


with open( input_filename + '.yml', 'r' ) as stream:
               
            
            
            input_dict = yaml.load(stream, Loader=yaml.SafeLoader)
            

            directory	=input_dict['control']['folder']
 

path = f"{os.getcwd()}{os.sep}Photon_Density{os.sep}{directory}{os.sep}Yml_Files"



os.mkdir(f'{os.getcwd()}{os.sep}Photon_Density{os.sep}{directory}{os.sep}H_Five')




object = os.scandir(path)
print("Files and Directories in '% s':" % path)
for n in object :
    





        luxeics.main_program(  f'{path}{os.sep}{n.name}' )
        print(n.name)
object.close()
# Out:
# Files and Directories in 'C:\Users\Dupish\Documents\GitHub\luxeics\Photon_Density\Sigmax_Sigmay5_L_3_8\Yml_Files':
# >>> mode == full
# [10000000, 10000000, 10000000, 10000000, 10000000, 10000000, 10000000, 10000000, 10000000, 10000000] 100000000 100000000
#  >> rescale pulse duration: 8549.40 -> 800.00: sigma_rescalefactor = 10.69
#  >> number_electrons   = 624150947
#  >> sample_electrons   = 100000000
#  >> electron weight    = 6.242
#  >> MC sampling
#   > batch 0 : 10000000 macroelectrons
#    base photon weight : 32.81601574528913
#    number photons     : 252
#    total photon number: 252
#   > batch 1 : 10000000 macroelectrons
#    base photon weight : 35.12566701991308
#    number photons     : 195
#    total photon number: 447
#   > batch 2 : 10000000 macroelectrons
#    base photon weight : 34.879788643657264
#    number photons     : 219
#    total photon number: 666
#   > batch 3 : 10000000 macroelectrons
#    base photon weight : 35.7166545471013
# ...

# %%
import os
import tqdm

import luxeics

import yaml
input_filename = f"{os.getcwd()}{os.sep}YML_Files{os.sep}L_3_8{os.sep}Sigmax_Sigmay10"


with open( input_filename + '.yml', 'r' ) as stream:
               
            
            
            input_dict = yaml.load(stream, Loader=yaml.SafeLoader)
            

            directory	=input_dict['control']['folder']
 

path = f"{os.getcwd()}{os.sep}Photon_Density{os.sep}{directory}{os.sep}Yml_Files"



os.mkdir(f'{os.getcwd()}{os.sep}Photon_Density{os.sep}{directory}{os.sep}H_Five')




object = os.scandir(path)
print("Files and Directories in '% s':" % path)
for n in object :
    





        luxeics.main_program(  f'{path}{os.sep}{n.name}' )
        print(n.name)
object.close()
# Out:
# Files and Directories in 'C:\Users\Dupish\Documents\GitHub\luxeics\Photon_Density\Sigmax_Sigmay10_L_3_8\Yml_Files':
# >>> mode == full
# [10000000, 10000000, 10000000, 10000000, 10000000, 10000000, 10000000, 10000000, 10000000, 10000000] 100000000 100000000
#  >> rescale pulse duration: 8549.40 -> 800.00: sigma_rescalefactor = 10.69
#  >> number_electrons   = 624150947
#  >> sample_electrons   = 100000000
#  >> electron weight    = 6.242
#  >> MC sampling
#   > batch 0 : 10000000 macroelectrons
#    base photon weight : 41.47463627246762
#    number photons     : 503
#    total photon number: 503
#   > batch 1 : 10000000 macroelectrons
#    base photon weight : 36.82511921162531
#    number photons     : 563
#    total photon number: 1066
#   > batch 2 : 10000000 macroelectrons
#    base photon weight : 35.70879742585192
#    number photons     : 614
#    total photon number: 1680
#   > batch 3 : 10000000 macroelectrons
#    base photon weight : 37.986113528034004
# ...

# %%
import os
import tqdm

import luxeics

import yaml
input_filename = f"{os.getcwd()}{os.sep}YML_Files{os.sep}L_3_8{os.sep}Sigmax_Sigmay15"


with open( input_filename + '.yml', 'r' ) as stream:
               
            
            
            input_dict = yaml.load(stream, Loader=yaml.SafeLoader)
            

            directory	=input_dict['control']['folder']
 

path = f"{os.getcwd()}{os.sep}Photon_Density{os.sep}{directory}{os.sep}Yml_Files"



os.mkdir(f'{os.getcwd()}{os.sep}Photon_Density{os.sep}{directory}{os.sep}H_Five')




object = os.scandir(path)
print("Files and Directories in '% s':" % path)
for n in object :
    





        luxeics.main_program(  f'{path}{os.sep}{n.name}' )
        print(n.name)
object.close()
# Out:
# Files and Directories in 'C:\Users\Dupish\Documents\GitHub\luxeics\Photon_Density\Sigmax_Sigmay15_L_3_8\Yml_Files':
# >>> mode == full
# [10000000, 10000000, 10000000, 10000000, 10000000, 10000000, 10000000, 10000000, 10000000, 10000000] 100000000 100000000
#  >> rescale pulse duration: 8549.40 -> 800.00: sigma_rescalefactor = 10.69
#  >> number_electrons   = 624150947
#  >> sample_electrons   = 100000000
#  >> electron weight    = 6.242
#  >> MC sampling
#   > batch 0 : 10000000 macroelectrons
#    base photon weight : 37.17897389258206
#    number photons     : 617
#    total photon number: 617
#   > batch 1 : 10000000 macroelectrons
#    base photon weight : 40.81135198818164
#    number photons     : 599
#    total photon number: 1216
#   > batch 2 : 10000000 macroelectrons
#    base photon weight : 40.84423647254163
#    number photons     : 584
#    total photon number: 1800
#   > batch 3 : 10000000 macroelectrons
#    base photon weight : 39.8673626403728
# ...

# %%
import os
import tqdm

import luxeics

import yaml
input_filename = f"{os.getcwd()}{os.sep}YML_Files{os.sep}L_3_8{os.sep}Sigmax_Sigmay20"


with open( input_filename + '.yml', 'r' ) as stream:
               
            
            
            input_dict = yaml.load(stream, Loader=yaml.SafeLoader)
            

            directory	=input_dict['control']['folder']
 

path = f"{os.getcwd()}{os.sep}Photon_Density{os.sep}{directory}{os.sep}Yml_Files"



os.mkdir(f'{os.getcwd()}{os.sep}Photon_Density{os.sep}{directory}{os.sep}H_Five')




object = os.scandir(path)
print("Files and Directories in '% s':" % path)
for n in object :
    





        luxeics.main_program(  f'{path}{os.sep}{n.name}' )
        print(n.name)
object.close()
# Out:
# Files and Directories in 'C:\Users\Dupish\Documents\GitHub\luxeics\Photon_Density\Sigmax_Sigmay20_L_3_8\Yml_Files':
# >>> mode == full
# [10000000, 10000000, 10000000, 10000000, 10000000, 10000000, 10000000, 10000000, 10000000, 10000000] 100000000 100000000
#  >> rescale pulse duration: 8549.40 -> 800.00: sigma_rescalefactor = 10.69
#  >> number_electrons   = 624150947
#  >> sample_electrons   = 100000000
#  >> electron weight    = 6.242
#  >> MC sampling
#   > batch 0 : 10000000 macroelectrons
#    base photon weight : 35.27213649433859
#    number photons     : 497
#    total photon number: 497
#   > batch 1 : 10000000 macroelectrons
#    base photon weight : 38.366891536245774
#    number photons     : 474
#    total photon number: 971
#   > batch 2 : 10000000 macroelectrons
#    base photon weight : 34.313429260853574
#    number photons     : 541
#    total photon number: 1512
#   > batch 3 : 10000000 macroelectrons
#    base photon weight : 35.60637352282631
# ...

# %%
import os
import tqdm

import luxeics

import yaml
input_filename = f"{os.getcwd()}{os.sep}YML_Files{os.sep}L_3_8{os.sep}Sigmax_Sigmay25"


with open( input_filename + '.yml', 'r' ) as stream:
               
            
            
            input_dict = yaml.load(stream, Loader=yaml.SafeLoader)
            

            directory	=input_dict['control']['folder']
 

path = f"{os.getcwd()}{os.sep}Photon_Density{os.sep}{directory}{os.sep}Yml_Files"



os.mkdir(f'{os.getcwd()}{os.sep}Photon_Density{os.sep}{directory}{os.sep}H_Five')




object = os.scandir(path)
print("Files and Directories in '% s':" % path)
for n in object :
    





        luxeics.main_program(  f'{path}{os.sep}{n.name}' )
        print(n.name)
object.close()
# Out:
# Files and Directories in 'C:\Users\Dupish\Documents\GitHub\luxeics\Photon_Density\Sigmax_Sigmay25_L_3_8\Yml_Files':
# >>> mode == full
# [10000000, 10000000, 10000000, 10000000, 10000000, 10000000, 10000000, 10000000, 10000000, 10000000] 100000000 100000000
#  >> rescale pulse duration: 8549.40 -> 800.00: sigma_rescalefactor = 10.69
#  >> number_electrons   = 624150947
#  >> sample_electrons   = 100000000
#  >> electron weight    = 6.242
#  >> MC sampling
#   > batch 0 : 10000000 macroelectrons
#    base photon weight : 38.35926660419864
#    number photons     : 315
#    total photon number: 315
#   > batch 1 : 10000000 macroelectrons
#    base photon weight : 36.25692631411429
#    number photons     : 328
#    total photon number: 643
#   > batch 2 : 10000000 macroelectrons
#    base photon weight : 38.85126018811903
#    number photons     : 316
#    total photon number: 959
#   > batch 3 : 10000000 macroelectrons
#    base photon weight : 31.96804979693243
# ...
